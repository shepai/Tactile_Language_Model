# %% [markdown]
# # Decision analysis
#
# Analyse the data from the Large Language Model outputs.

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd

# %%
df=pd.read_csv("/its/home/drs25/Tactile_Language_Model/data/Conceptual.csv")
df.head()
# Out:
#    Unnamed: 0     ID                                               text  \
# 0           0  44114  sphere shape; force 0.11877596874957905 newton...
# 1           1  20181  sphere shape; force 0.11414840966615554 newton...
# 2           2  85036  Texture bronze_bushing_massive; force 23.99121...
# 3           3  90372  Texture crown_eraser; force 18.910441159273876...
# 4           4  18739  sphere shape; force 0.1834305363113434 newtons...
#
#                                                gemma  \
# 0  Okay; processing… tactile input received. Sphe...
# 1  Okay; processing tactile input…  Speed action:...
# 2  speed action: reduce leg spread action: increa...
# 3  speed action: decrease leg spread action: wide...
# 4  Okay; processing tactile input... Analyzing......
#
#                                               llamas  \
# 0  I detect a gentle; spherical object beneath my...
# 1  What a delightful scenario! I've received tact...
# 2  Interesting sensor reading! Based on my tactil...
# 3  Interesting tactile feedback! Based on the sen...
# 4  I'm receiving tactile sensor readings from my ...
#
#                                                  gpt  \
# 0  speed action: no action   leg spread action: w...
# 1  speed action: reduce speed   leg spread action...
# 2  speed action: Maintain current speed – the sur...
# 3  speed action: slow_down   leg spread action: i...
# 4  speed action: maintain current speed (no chang...
#
#                                              mistral  \
# 0   Based on the tactile sensor reading you provi...
# 1   Based on the tactile sensor readings provided...
# 2   Based on the tactile sensor reading; I would ...
# 3   Based on the tactile sensor reading of a crow...
# 4   Based on the tactile sensor reading you provi...
#
#                                             deepseek  gemmaspeed  llamasspeed  \
# 0  <think> Okay; user wants me to simulate a quad...    6.251364     5.917915
# 1  <think> We are a quadruped robot with tactile ...    0.689211     1.396595
# 2  <think> First; I need to respond as a quadrupe...    0.573470     0.934896
# 3  4t = 1  have a can'tively    are not，I think 实...    0.534012     0.660611
# 4  ! IPhone a highlyersenough aact a't = a) have ...    0.725944     2.052315
#
#     gptspeed  deepseekspeed  mistralspeed
# 0  18.797326       7.180668      4.777751
# 1   7.603484      28.043513      2.945000
# 2  12.401291     496.946107      2.118879
# 3   6.434444     495.022935      2.294599
# 4  11.840395     171.162731      2.665445

# %%
df.describe()
# Out:
#         Unnamed: 0             ID   gemmaspeed  llamasspeed     gptspeed  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    499.500000   49584.130000     0.936777     1.396300     8.009419
# std     288.819436   28464.410322     0.325641     0.509538     3.220859
# min       0.000000     134.000000     0.439243     0.326162     1.895236
# 25%     249.750000   24176.250000     0.721012     1.017946     5.599614
# 50%     499.500000   48741.000000     0.818765     1.324498     7.659334
# 75%     749.250000   73147.750000     1.220857     1.691143     9.917437
# max     999.000000  100095.000000     6.251364     5.917915    24.327905
#
#        deepseekspeed  mistralspeed
# count    1000.000000   1000.000000
# mean        1.669914      2.573725
# std        22.805547      0.673174
# min         0.432916      0.854752
# 25%         0.465544      2.164451
# 50%         0.473804      2.550619
# 75%         0.482652      2.966777
# max       496.946107      5.266383

# %% [markdown]
# ## Functional

# %%
df_f=pd.read_csv("/its/home/drs25/Tactile_Language_Model/data/FunctionalModelOutputs.csv")

def countFunctions(df_f):
    new_df=pd.DataFrame({})
    new_df["gemma"] = df_f["gemma"].str.findall(r'(\w+)\s*\(')
    new_df["mistral"] = df_f["mistral"].str.findall(r'(\w+)\s*\(')
    new_df["gpt"] = df_f["gpt"].str.findall(r'(\w+)\s*\(')
    new_df["llamas"] = df_f["llamas"].str.findall(r'(\w+)\s*\(')
    #new_df["deepseek"] = df_f["deepseek"].str.findall(r'(\w+)\s*\(')


    allowed_funcs = ["increaseSpeed", "slowSpeed","maintainSpeed","widenLegStride","maintainLegSTride","increaseLegStride","lowerBody","maintainBody","IncreaseBody"]

    new_df["gemma"] = new_df["gemma"].apply(lambda funcs: [f for f in funcs if f in allowed_funcs])
    new_df["mistral"] = new_df["mistral"].apply(lambda funcs: [f for f in funcs if f in allowed_funcs])
    new_df["gpt"] = new_df["gpt"].apply(lambda funcs: [f for f in funcs if f in allowed_funcs])
    new_df["llamas"] = new_df["llamas"].apply(lambda funcs: [f for f in funcs if f in allowed_funcs])
    #new_df["deepseek"] = new_df["deepseek"].apply(lambda funcs: [f for f in funcs if f in allowed_funcs])

    for func in allowed_funcs:
        new_df[f"{func}"] = new_df["gemma"].apply(lambda funcs: funcs.count(func))
        new_df[f"{func}"] += new_df["mistral"].apply(lambda funcs: funcs.count(func))
        new_df[f"{func}"] += new_df["gpt"].apply(lambda funcs: funcs.count(func))
        new_df[f"{func}"] += new_df["llamas"].apply(lambda funcs: funcs.count(func))
        #new_df[f"{func}"] += new_df["deepseek"].apply(lambda funcs: funcs.count(func))
    return new_df
new_df=countFunctions(df_f)
new_df.head()
# Out:
#                                               gemma  \
# 0  [maintainSpeed, maintainLegSTride, maintainBody]
# 1  [maintainSpeed, maintainLegSTride, maintainBody]
# 2  [maintainSpeed, maintainLegSTride, maintainBody]
# 3  [maintainSpeed, maintainLegSTride, maintainBody]
# 4  [maintainSpeed, maintainLegSTride, maintainBody]
#
#                                             mistral  \
# 0  [maintainSpeed, increaseLegStride, maintainBody]
# 1     [maintainSpeed, widenLegStride, maintainBody]
# 2        [maintainSpeed, widenLegStride, lowerBody]
# 3                     [maintainSpeed, maintainBody]
# 4                        [maintainSpeed, lowerBody]
#
#                                                 gpt  \
# 0                     [maintainSpeed, maintainBody]
# 1  [maintainSpeed, maintainLegSTride, maintainBody]
# 2            [slowSpeed, widenLegStride, lowerBody]
# 3        [maintainSpeed, widenLegStride, lowerBody]
# 4  [maintainSpeed, increaseLegStride, maintainBody]
#
#                                           llamas  increaseSpeed  slowSpeed  \
# 0     [maintainSpeed, widenLegStride, lowerBody]              0          0
# 1     [maintainSpeed, widenLegStride, lowerBody]              0          0
# 2     [maintainSpeed, widenLegStride, lowerBody]              0          1
# 3  [maintainSpeed, widenLegStride, maintainBody]              0          0
# 4  [maintainSpeed, widenLegStride, maintainBody]              0          0
#
#    maintainSpeed  widenLegStride  maintainLegSTride  increaseLegStride  \
# 0              4               1                  1                  1
# 1              4               2                  2                  0
# 2              3               3                  1                  0
# 3              4               2                  1                  0
# 4              4               1                  1                  1
#
#    lowerBody  maintainBody  IncreaseBody
# 0          1             3             0
# 1          1             3             0
# 2          3             1             0
# 3          1             3             0
# 4          1             3             0

# %%
#count percentages
def countPercentage(new_df):
    speed_func=["increaseSpeed", "slowSpeed","maintainSpeed"]
    strid_func=["widenLegStride","maintainLegSTride","increaseLegStride"]
    body_func=["lowerBody","maintainBody","IncreaseBody"]
    models = ["gemma", "mistral","gpt","llamas"] 
    all_funcs = speed_func + strid_func + body_func
      # <- add your models here

    for model in models:
        for func in all_funcs:
            new_df[f"{model}_{func}"] = new_df[model].apply(lambda funcs: funcs.count(func))

    new_df["Speed_max"] = new_df[[f"{m}_{f}" for m in models for f in speed_func]].sum(axis=1)
    new_df["Stride_max"] = new_df[[f"{m}_{f}" for m in models for f in strid_func]].sum(axis=1)
    new_df["Body_max"] = new_df[[f"{m}_{f}" for m in models for f in body_func]].sum(axis=1)

    
    new_df["winning_category"] = new_df[["Speed_max","Stride_max","Body_max"]].idxmax(axis=1)

    def model_in_winning_vote(row, model_prefix):
        cat = row["winning_category"]
        if cat == "Speed_max":
            return row[[f"{model_prefix}_{f}" for f in speed_func]].sum() > 0
        elif cat == "Stride_max":
            return row[[f"{model_prefix}_{f}" for f in strid_func]].sum() > 0
        elif cat == "Body_max":
            return row[[f"{model_prefix}_{f}" for f in body_func]].sum() > 0
        return False

    for model in models:
        new_df[f"{model}_in_win"] = new_df.apply(model_in_winning_vote, axis=1, args=(model,))
    for model in models:
        print(model, "win rate:", new_df[f"{model}_in_win"].mean())
    return new_df

new_df=countPercentage(new_df)
new_df.head()
# Out:
# gemma win rate: 1.0
# mistral win rate: 1.0
# gpt win rate: 1.0
# llamas win rate: 0.998
#                                               gemma  \
# 0  [maintainSpeed, maintainLegSTride, maintainBody]
# 1  [maintainSpeed, maintainLegSTride, maintainBody]
# 2  [maintainSpeed, maintainLegSTride, maintainBody]
# 3  [maintainSpeed, maintainLegSTride, maintainBody]
# 4  [maintainSpeed, maintainLegSTride, maintainBody]
#
#                                             mistral  \
# 0  [maintainSpeed, increaseLegStride, maintainBody]
# 1     [maintainSpeed, widenLegStride, maintainBody]
# 2        [maintainSpeed, widenLegStride, lowerBody]
# 3                     [maintainSpeed, maintainBody]
# 4                        [maintainSpeed, lowerBody]
#
#                                                 gpt  \
# 0                     [maintainSpeed, maintainBody]
# 1  [maintainSpeed, maintainLegSTride, maintainBody]
# 2            [slowSpeed, widenLegStride, lowerBody]
# 3        [maintainSpeed, widenLegStride, lowerBody]
# 4  [maintainSpeed, increaseLegStride, maintainBody]
#
#                                           llamas  increaseSpeed  slowSpeed  \
# 0     [maintainSpeed, widenLegStride, lowerBody]              0          0
# 1     [maintainSpeed, widenLegStride, lowerBody]              0          0
# 2     [maintainSpeed, widenLegStride, lowerBody]              0          1
# 3  [maintainSpeed, widenLegStride, maintainBody]              0          0
# 4  [maintainSpeed, widenLegStride, maintainBody]              0          0
#
#    maintainSpeed  widenLegStride  maintainLegSTride  increaseLegStride  ...  \
# 0              4               1                  1                  1  ...
# 1              4               2                  2                  0  ...
# 2              3               3                  1                  0  ...
# 3              4               2                  1                  0  ...
# 4              4               1                  1                  1  ...
#
#    llamas_maintainBody  llamas_IncreaseBody  Speed_max  Stride_max  Body_max  \
# 0                    0                    0          4           3         4
# 1                    0                    0          4           4         4
# 2                    0                    0          4           4         4
# 3                    1                    0          4           3         4
# 4                    1                    0          4           3         4
#
#    winning_category  gemma_in_win  mistral_in_win  gpt_in_win  llamas_in_win
# 0         Speed_max          True            True        True           True
# 1         Speed_max          True            True        True           True
# 2         Speed_max          True            True        True           True
# 3         Speed_max          True            True        True           True
# 4         Speed_max          True            True        True           True
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Cosine analysis

# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('all-MiniLM-L6-v2')

# %%
cosine_frame=pd.DataFrame({
    "gemma-gpt":[0 for i in range(len(df['gemma']))],
    "gemma-deepseek":[0 for i in range(len(df['gemma']))],
    "gemma-llamas":[0 for i in range(len(df['gemma']))],
    "gemma-mistral":[0 for i in range(len(df['gemma']))],
    "deepseek-gpt":[0 for i in range(len(df['gemma']))],
    "deepseek-llamas":[0 for i in range(len(df['gemma']))],
    "deepseek-mistral":[0 for i in range(len(df['gemma']))],
    "gpt-llamas":[0 for i in range(len(df['gemma']))],
    "gpt-mistral":[0 for i in range(len(df['gemma']))],
})

keys=list(cosine_frame.keys())
for i in range(len(keys)):
    print(i/len(keys)*100,"%")
    key=keys[i]
    models=key.split("-")
    textA=df[models[0]]
    textB=df[models[1]]
    ar=[]
    for j in range(len(df[models[0]])):
        if not pd.isnull(textA[j]) and not pd.isnull(textB[j]):
            embedding1 = model.encode(textA[j], convert_to_tensor=True)
            embedding2 = model.encode(textB[j], convert_to_tensor=True)
            cosine_sim = util.pytorch_cos_sim(embedding1, embedding2)
            ar.append(cosine_sim.item())
        else:
            ar.append(0)
    cosine_frame[key]=ar
    cosine_frame.to_csv("/its/home/drs25/Tactile_Language_Model/data/Cosine_model_decision.csv")

cosine_frame
# Out:
# 0.0 %
# /its/home/drs25/.local/lib/python3.10/site-packages/torch/nn/modules/module.py:1747: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `BertSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# 11.11111111111111 %
# 22.22222222222222 %
# 33.33333333333333 %
# 44.44444444444444 %
# 55.55555555555556 %
# 66.66666666666666 %
# 77.77777777777779 %
# 88.88888888888889 %
#      gemma-gpt  gemma-deepseek  gemma-llamas  gemma-mistral  deepseek-gpt  \
# 0     0.574377        0.566394      0.658104       0.668135      0.258157
# 1     0.716906        0.617438      0.579660       0.475780      0.616972
# 2     0.777515        0.202569      0.521569       0.422305      0.337706
# 3     0.926331        0.028440      0.591525       0.407994      0.064711
# 4     0.616556        0.149257      0.569379       0.574875      0.148592
# ..         ...             ...           ...            ...           ...
# 995   0.497664        0.009600      0.673914       0.547261      0.007755
# 996   0.463995        0.085627      0.649517       0.497181     -0.022310
# 997   0.746500        0.016891      0.546417       0.342500     -0.007390
# 998   0.858429        0.048491      0.681157       0.423660      0.033819
# 999   0.625149        0.081417      0.571885       0.460404      0.004574
#
#      deepseek-llamas  deepseek-mistral  gpt-llamas  gpt-mistral
# 0           0.516537          0.636687    0.481046     0.373510
# 1           0.689841          0.759830    0.393533     0.382770
# 2           0.651127          0.600886    0.629294     0.629351
# 3           0.008814          0.052503    0.591548     0.420415
# 4           0.024506          0.006856    0.453952     0.414204
# ..               ...               ...         ...          ...
# 995         0.106617          0.090409    0.480759     0.475424
# 996         0.122260          0.101377    0.522477     0.612118
# 997         0.145615          0.140059    0.572010     0.471225
# 998         0.121582          0.115136    0.660576     0.442368
# 999         0.013392          0.097482    0.645152     0.542482
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Similarity over trials

# %%
#load in data results
df0=pd.read_csv("/its/home/drs25/Tactile_Language_Model/data/Functional.csv")
df1=pd.read_csv("/its/home/drs25/Tactile_Language_Model/data/Functional copy.csv")

df0=countFunctions(df0)
df0=countPercentage(df0)
df0.head()

df1=countFunctions(df1)
df1=countPercentage(df1)
df1.head()

#count across how many were the same
functions=["increaseSpeed", "slowSpeed","maintainSpeed","widenLegStride","maintainLegSTride","increaseLegStride","lowerBody","maintainBody","IncreaseBody"]
models = ["gemma", "mistral","gpt","llamas"] 
total=0
count=0
for i in range(len(models)):
    for j in range(len(functions)):
        count += ((df0[str(models[i])+"_"+str(functions[j])] == df1[str(models[i])+"_"+str(functions[j])])).sum()
        total += len(df0[str(models[i])+"_"+str(functions[j])])

print("\n\tTotal  accuracy:",count/total *100,"%")
# Out:
# gemma win rate: 0.999
# mistral win rate: 0.999
# gpt win rate: 1.0
# llamas win rate: 1.0
# gemma win rate: 0.999
# mistral win rate: 0.999
# gpt win rate: 1.0
# llamas win rate: 1.0
#
# 	Total  accuracy: 100.0 %
